# %%
import time
import pandas as pd
from geopy import Nominatim
geolocator = Nominatim()

# %% [markdown]
# ## Import Dataset

# %%
dir = "C:/Users/David/Dropbox/Skills/Python/Projects/Real_Estate/htx_real_estate_analysis/"
file = pd.read_csv(dir+"all_details_08252017.csv")

# %%
file['zip_str'] = file['Zip Code'].astype(int)
file['zip_str'] = file['zip_str'].astype(str)

# %%
file['address_full'] = file['Address']+" "+file['City']+" "+file['zip_str']
file['lat'] = ""
file['lon'] = ""

# %%
file = file[["address_full","lat","lon"]]

# %% [markdown]
# ## Collection of Address Locations (Lat&Lon)

# %%
for idx,row in file.iterrows():
    try:
        location = geolocator.geocode(row['address_full'])
        file.set_value(idx,'lat',location.latitude)
        file.set_value(idx,'lon',location.longitude)
    except:
        continue
    if idx % 200 == 0:
        print(idx)
    time.sleep(1)
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400

# %%
# file['lat'].value_counts(dropna=False)

# %%
file.to_csv(dir+"home_addresses_latlon_082582017.csv")

# %% [markdown]
# ## Collection of Walk,Transit,Bike Scores

# %%
file['lat'] = file['lat'].astype(str)
file['lon'] = file['lon'].astype(str)
file['bike_score'] = ""
file['transit_score'] = ""
file['walk_score'] = ""
# Out:
# C:\Users\David\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\David\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\David\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\David\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\David\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
for idx, row in file.iterrows():
    if row['lat'] != "":
        addr = row['address_full']
        addr = addr.replace(" ","%20")
        lat = row['lat']
        lon = row['lon']
        addr_base = "http://api.walkscore.com/score?format=json&address="
        addr_base = addr_base + addr + "&lat=" + lat + "&lon=" + lon + "&transit=1" + "&bike=1" + "&wsapikey=33a9c4ba9c6f64219f47475fa9e7fd65"
        try:
            jsonurl = urlopen(addr_base)
            text = json.loads(jsonurl.read())
            scores_df = pd.DataFrame.from_dict(text)
            bike_score = scores_df.loc["score","bike"]
            transit_score = scores_df.loc["score","transit"]
            walk_score = scores_df.loc["score","walkscore"]
            file.set_value(idx,"bike_score",bike_score)
            file.set_value(idx,"transit_score",transit_score)
            file.set_value(idx,"walk_score",walk_score)
            del scores_df
        except:
            continue
        if idx % 200 == 0:
            print(idx)
        time.sleep(1)
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400

# %%
file
# Out:
#                              address_full         lat          lon bike_score  \
# 0               0 E 39th St Houston 77018
# 1            10 N Hutcheson Houston 77003
# 2            10 N Hutcheson Houston 77003
# 3                 1001 21st Houston 77008  29.8050758  -95.3911047         65
# 4               1001 W 21st Houston 77008
# 5             1001 W 8th St Houston 77007   29.785086   -95.403271         75
# 6            1002 E 25th St Houston 77009  29.8089024  -95.3958918         62
# 7           1005 Bingham #2 Houston 77007  29.7717963  -95.3700728
# 8           1005 Bingham #2 Houston 77007  29.7717963  -95.3700728
# 9           1005 Bingham #3 Houston 77007  29.7717963  -95.3700728
# 10          1005 Bingham #3 Houston 77007  29.7717963  -95.3700728
# 11         1009 St. Charles Houston 77003
# 12         1010 E Temple St Houston 77009
# 13           1010 Studer St Houston 77007  29.7725768   -95.415454         65
# 14        1010 W 24th St #D Houston 77008
# 15        1010 W 24th St #F Houston 77008
# 16    1011 Green Kensington Houston 77008
# 17           1012 Archer St Houston 77009  29.7971341  -95.3738203         50
# 18        1012 E 7th 1/2 St Houston 77009
# 19           1013 E 27th St Houston 77009  29.8114386  -95.3924352         59
# 20            1014 Adele St Houston 77009   29.806053   -95.386179         62
# 21           1014 E 16th St Houston 77009   29.799838   -95.386188         61
# 22    1014 Green Kensington Houston 77008
# 23    1015 Green Kensington Houston 77008
# 24            1016 Adele St Houston 77009   29.806053   -95.386179         62
# 25              1016 Fugate Houston 77009
# 26        1016 W Cottage St Houston 77009  29.7922555  -95.3860703         64
# 27           1016A Lawrence Houston 77008   29.813772   -95.408224         66
# 28           1017 E 26th St Houston 77009   29.811219   -95.383754         59
# 29             1018 Omar St Houston 77009   29.788054   -95.384311         65
# ...                                   ...         ...          ...        ...
# 1549       923 Chantilly Ln Houston 77018   29.828882    -95.44152         43
# 1550       923 Chantilly Ln Houston 77018   29.828882    -95.44152         43
# 1551      925 Tulane Street Houston 77008  29.7924602  -95.4023089         70
# 1552          926 Prince St Houston 77008  29.7903249  -95.4134053         68
# 1553          926 W 26th St Houston 77008   29.809843   -95.414797         58
# 1554          927 Fugate St Houston 77009   29.795037  -95.3762929         50
# 1555        927 Gardenia Dr Houston 77018   29.827032   -95.424159         62
# 1556          928 Louise St Houston 77009  29.8053479  -95.3844428         63
# 1557   928 Mckinney Park Ln Houston 77003
# 1558        929 Wynnwood Ln Houston 77008   29.793986   -95.440727         46
# 1559       9305 Highlawn St Houston 77022  29.8455634   -95.374767         44
# 1560          931 W 17th St Houston 77008   29.800744   -95.410088         68
# 1561         9314 Olathe St Houston 77055   29.796887   -95.515931         63
# 1562   933 W 24th St Unit E Houston 77008
# 1563           934 Hillstar Houston 77009
# 1564             934 Robbie Houston 77009  29.8046329  -95.3844365         63
# 1565       939 Colorado #10 Houston 77007   29.770765   -95.374701
# 1566         94 N Hutcheson Houston 77003   29.756543   -95.332424         73
# 1567          947 W 41st St Houston 77018  29.8242419  -95.4203199         67
# 1568          949 W 24th St Houston 77008   29.807757   -95.418138         58
# 1569          953 W 23rd St Houston 77008  29.8066926  -95.4224409         66
# 1570         953 Yale St  B Houston 77008
# 1571         953 Yale St  B Houston 77008
# 1572        955 W 24 Unit C Houston 77008
# 1573         96 N Hutcheson Houston 77003   29.756543   -95.332424         73
# 1574       960 Patterson St Houston 77007  29.7769985  -95.4062857         57
# 1575       962 Del Norte St Houston 77018   29.839821   -95.449523         38
# 1576      9802 Pine Lake Dr Houston 77055   29.789017   -95.534467         52
# 1577      9815 Oak Point Dr Houston 77055   29.792698   -95.534428         49
# 1578      9829 Pine Lake Dr Houston 77055   29.789017   -95.534467         52
#
#      transit_score walk_score
# 0
# 1
# 2
# 3               47         69
# 4
# 5               42         52
# 6               43         69
# 7
# 8
# 9
# 10
# 11
# 12
# 13              42         82
# 14
# 15
# 16
# 17              56         67
# 18
# 19              44         59
# 20              46         69
# 21              46         77
# 22
# 23
# 24              46         69
# 25
# 26              47         78
# 27              42         57
# 28              47         64
# 29              45         75
# ...            ...        ...
# 1549            37         45
# 1550            37         45
# 1551            43         63
# 1552            37         64
# 1553            42         55
# 1554            54         69
# 1555            43         55
# 1556            47         71
# 1557
# 1558            40         35
# 1559            41         61
# 1560            44         76
# 1561            35         68
# 1562
# 1563
# 1564            47         71
# 1565
# 1566            48         53
# 1567            44         46
# 1568            41         54
# 1569            38         67
# 1570
# 1571
# 1572
# 1573            48         53
# 1574            45         75
# 1575            34          4
# 1576            40         59
# 1577            38         52
# 1578            40         59
#
# [1579 rows x 6 columns]

# %%
file.to_csv(dir+"home_addresses_latlon_walkscores_08252017.csv")
